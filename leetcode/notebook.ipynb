# %%
from bisect import bisect_left
n = [0,1,3,5,6]
print(bisect_left(n,5))
# Out:
# 3

# %%
from bisect import bisect_left
n = [0,1,3,4,6]
print(bisect_left(n,5))
# Out:
# 4

# %%
import heapq
heap = []
heapq.heappush(heap, 5)
heapq.heappush(heap, 2)
heapq.heappush(heap, 8)
print(heap)
# Out:
# [2, 5, 8]

# %%
import heapq
heap = []
heapq.heappush(heap, 5)
heapq.heappush(heap, 2)
heapq.heappush(heap, 8)
heapq.heappush(heap, 3)
heapq.heappush(heap, 1)
print(heap)
# Out:
# [1, 2, 8, 5, 3]

# %%
import heapq
heap = []
heapq.heappush(heap, 5)
heapq.heappush(heap, 2)
heapq.heappush(heap, 8)
heapq.heappush(heap, 3)
heapq.heappush(heap, 1)
heapq.heappush(heap, 4)
heapq.heappush(heap, 6)
print(heap)
# Out:
# [1, 2, 4, 5, 3, 8, 6]
