# %%
from bisect import bisect_left
n = [0,1,3,5,6]
print(bisect_left(n,5))
# Out:
# 3

# %%
from bisect import bisect_left
n = [0,1,3,4,6]
print(bisect_left(n,5))
# Out:
# 4
